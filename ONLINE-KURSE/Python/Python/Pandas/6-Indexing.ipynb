# %% [markdown]
# # 6 - Indxing

# %% [markdown]
# ## 1 - Index
# * Index-Object ist eine Array
# * man kann mit Index-Obj Row oder Columns erreichen

# %%
import pandas as pd

oo = pd.read_csv('./ALL MEDALISTS.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
type(oo.index) # index ist Attribute von pd.DataFrame-Typ
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
oo.index[100]
# Out:
# 100

# %% [markdown]
# * Index ist immutable .dh man kann index nicht ändern

# %%
oo.index[100] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-389-208e002ccef5> in <module>
# ----> 1 oo.index[100] = 5
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    3907
#    3908     def __setitem__(self, key, value):
# -> 3909         raise TypeError("Index does not support mutable operations")
#    3910
#    3911     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %% [markdown]
# ## 2 - Using set_index()
# + `set_index(keys, drop=True, append=False, inplace=True, verify_integriy=False)` = welche Series sollte Index sein
# * per Default ist Index die erste Row mit 0..n

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.set_index('Athlete') # Spalte Athlet zum Index setzen
# Out:
#                          City  Edition      Sport       Discipline  NOC  \
# Athlete
# HAJOS, Alfred          Athens     1896   Aquatics         Swimming  HUN
# HERSCHMANN, Otto       Athens     1896   Aquatics         Swimming  AUT
# DRIVAS, Dimitrios      Athens     1896   Aquatics         Swimming  GRE
# MALOKINIS, Ioannis     Athens     1896   Aquatics         Swimming  GRE
# CHASAPIS, Spiridon     Athens     1896   Aquatics         Swimming  GRE
# ...                       ...      ...        ...              ...  ...
# ENGLICH, Mirko        Beijing     2008  Wrestling  Wrestling Gre-R  GER
# MIZGAITIS, Mindaugas  Beijing     2008  Wrestling  Wrestling Gre-R  LTU
# PATRIKEEV, Yuri       Beijing     2008  Wrestling  Wrestling Gre-R  ARM
# LOPEZ, Mijain         Beijing     2008  Wrestling  Wrestling Gre-R  CUB
# BAROEV, Khasan        Beijing     2008  Wrestling  Wrestling Gre-R  RUS
#
#                      Gender                       Event Event_gender   Medal
# Athlete
# ...

# %%
oo.head() # da nicht inplace=True wurde pandas-Array nicht überschrieben
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.set_index('Athlete', inplace=True)

# %%
oo.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
oo.reset_index(inplace=True)

# %%
oo_Athlete = oo.set_index('Athlete')
oo_Athlete.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
oo_NOC = oo.set_index('NOC')
oo_NOC.head()
# Out:
#                 Athlete    City  Edition     Sport Discipline Gender  \
# NOC
# HUN       HAJOS, Alfred  Athens     1896  Aquatics   Swimming    Men
# AUT    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming    Men
# GRE   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming    Men
# GRE  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming    Men
# GRE  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming    Men
#
#                           Event Event_gender   Medal
# NOC
# HUN              100m freestyle            M    Gold
# AUT              100m freestyle            M  Silver
# GRE  100m freestyle for sailors            M  Bronze
# GRE  100m freestyle for sailors            M    Gold
# GRE  100m freestyle for sailors            M  Silver

# %% [markdown]
# ## 3 - Using reset_index()
# * `reset_idnex(level=None, drop=False, inplace=False, ..)` - Index auf Default zurücksetzen

# %%
oo_Athlete.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
oo_Athlete.reset_index()
# Out:
#                     Athlete     City  Edition      Sport       Discipline  \
# 0             HAJOS, Alfred   Athens     1896   Aquatics         Swimming
# 1          HERSCHMANN, Otto   Athens     1896   Aquatics         Swimming
# 2         DRIVAS, Dimitrios   Athens     1896   Aquatics         Swimming
# 3        MALOKINIS, Ioannis   Athens     1896   Aquatics         Swimming
# 4        CHASAPIS, Spiridon   Athens     1896   Aquatics         Swimming
# ...                     ...      ...      ...        ...              ...
# 29211        ENGLICH, Mirko  Beijing     2008  Wrestling  Wrestling Gre-R
# 29212  MIZGAITIS, Mindaugas  Beijing     2008  Wrestling  Wrestling Gre-R
# 29213       PATRIKEEV, Yuri  Beijing     2008  Wrestling  Wrestling Gre-R
# 29214         LOPEZ, Mijain  Beijing     2008  Wrestling  Wrestling Gre-R
# 29215        BAROEV, Khasan  Beijing     2008  Wrestling  Wrestling Gre-R
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
oo_Athlete.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
oo_Athlete.reset_index(inplace=True)
oo_Athlete.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# ## 4 - Using sort_index()
# * `sort_index(axis=0, level=None, ascending=True, inplace=True,..., by=None)` - Array nach besimmten Index sortieren

# %%
oo_Athlete.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo_Athlete.set_index('Athlete', inplace=True)
oo_Athlete.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
ath.sort_index(inplace=True) # wird bei Index sortiert, da vorher auf Athlete gesetzt => wird by Athlete Name sortiert
ath.head()
# Out:
#                           index      City  Edition       Sport   Discipline  \
# Athlete
# AABYE, Edgar                651     Paris     1900  Tug of War   Tug of War
# AALTONEN, Arvo Ossian      2849   Antwerp     1920    Aquatics     Swimming
# AALTONEN, Arvo Ossian      2852   Antwerp     1920    Aquatics     Swimming
# AALTONEN, Paavo Johannes   8563  Helsinki     1952  Gymnastics  Artistic G.
# AALTONEN, Paavo Johannes   7730    London     1948  Gymnastics  Artistic G.
#
#                           NOC Gender              Event Event_gender   Medal
# Athlete
# AABYE, Edgar              ZZX    Men         tug of war            M    Gold
# AALTONEN, Arvo Ossian     FIN    Men  200m breaststroke            M  Bronze
# AALTONEN, Arvo Ossian     FIN    Men  400m breaststroke            M  Bronze
# AALTONEN, Paavo Johannes  FIN    Men   team competition            M  Bronze
# AALTONEN, Paavo Johannes  FIN    Men   team competition            M    Gold

# %%
ath.sort_index(inplace=True, ascending=False) # Index wird rückwärts sortiert (die Umlaute kommen nach Z)
ath.head()
# Out:
#                    index      City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# ÖSTRAND, Per-Olof   8051  Helsinki     1952  Aquatics   Swimming  SWE    Men
# ÖSTMO, Ole           596     Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole           621     Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole           608     Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole           603     Paris     1900  Shooting   Shooting  NOR    Men
#
#                                            Event Event_gender   Medal
# Athlete
# ÖSTRAND, Per-Olof                 400m freestyle            M  Bronze
# ÖSTMO, Ole         army rifle, 300m, 3 positions            M  Bronze
# ÖSTMO, Ole                      free rifle, team            M  Silver
# ÖSTMO, Ole            army rifle, 300m, standing            M  Silver
# ÖSTMO, Ole               army rifle, 300m, prone            M  Bronze

# %% [markdown]
# ## 5 - Using loc[]
# * `loc[]` - Label-basierter Index. wirft KeyError, wenn Item nicht gefunden
# * eigentlich nach Array Index auswählen (per default ist ja nummerischer Index und einmalig, wenn man aber Index wechselt mit `set_index` kann dann Index symbolisch und nicht mehr einmalig sein)

# %%
oo.loc['BOLT, Usain'] # Fehler, da Index der Default index ist (also nummerischer + einmaliger)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'BOLT, Usain'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-407-08ecb082094a> in <module>
# ----> 1 oo.loc['BOLT, Usain'] # Fehler, da Index der Default index ist (also nummerischer + einmaliger)
#
# ...

# %%
# loc[] Zugriff
oo.set_index('Athlete', inplace=True)
oo.loc['BOLT, Usain']
# Out:
#                 City  Edition      Sport Discipline  NOC Gender         Event  \
# Athlete
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          100m
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          200m
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men  4x100m relay
#
#             Event_gender Medal
# Athlete
# BOLT, Usain            M  Gold
# BOLT, Usain            M  Gold
# BOLT, Usain            M  Gold

# %%
# traditioneller Zugriff
oo.reset_index(inplace=True)
oo[oo.Athlete == 'BOLT, Usain']
# Out:
#            Athlete     City  Edition      Sport Discipline  NOC Gender  \
# 27552  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
# 27570  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
# 27603  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
#
#               Event Event_gender Medal
# 27552          100m            M  Gold
# 27570          200m            M  Gold
# 27603  4x100m relay            M  Gold

# %%
oo.loc[oo.Athlete == 'BOLT, Usain']
# Out:
#            Athlete     City  Edition      Sport Discipline  NOC Gender  \
# 27552  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
# 27570  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
# 27603  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
#
#               Event Event_gender Medal
# 27552          100m            M  Gold
# 27570          200m            M  Gold
# 27603  4x100m relay            M  Gold

# %% [markdown]
# ## 6 - Using iloc[]
# * `iloc[]` - Int-basierter Index der Axis (Also einmalig)
#     * ist auch nach Index-Wechsel erreichbar
#     + Vorteil: erlaubt Slices

# %%
oo.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.set_index('Athlete', inplace=True)
oo.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
oo.iloc[1700]
# Out:
# City             London
# Edition            1908
# Sport           Sailing
# Discipline      Sailing
# NOC                 FRA
# Gender              Men
# Event                6m
# Event_gender          X
# Medal            Bronze
# Name: RABOT, Pierre, dtype: object

# %%
oo.iloc[[1542, 2500, 6020, 15000]]
# Out:
#                                  City  Edition     Sport Discipline  NOC  \
# Athlete
# DUCKETT, Richard Louis         London     1908  Lacrosse   Lacrosse  CAN
# VETTER, Max                 Stockholm     1912    Rowing     Rowing  GER
# GAUDINI, Giulio           Los Angeles     1932   Fencing    Fencing  ITA
# JENSEN, Poul Richard Hoj     Montreal     1976   Sailing    Sailing  DEN
#
#                          Gender                                    Event  \
# Athlete
# DUCKETT, Richard Louis      Men                                 lacrosse
# VETTER, Max                 Men                 eight with coxswain (8+)
# GAUDINI, Giulio             Men                          foil individual
# JENSEN, Poul Richard Hoj    Men  fleet/match race keelboat open (Soling)
#
#                          Event_gender   Medal
# Athlete
# DUCKETT, Richard Louis              M    Gold
# VETTER, Max                         M  Bronze
# GAUDINI, Giulio                     M  Bronze
# ...

# %%
oo.iloc[1:4] # Bsp mit Python-Slices
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold

# %%
oo.reset_index(inplace=True)
oo.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# ## 7 - Challenge/Solution

# %% [markdown]
# 1. Anzahl der Medalien plotten, die bei jeder Olympia gewonnen wurden
# 2. Welche Länder haben keine Medalie in 2008 gewonnen

# %% [markdown]
# ### Meine Lösung

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

oo = pd.read_csv('./ALL MEDALISTS.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
# 1
oo.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
oo.Edition.value_counts().plot(kind='line');

# %%
oo_Edition = oo.Edition.value_counts()
oo_Edition
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
oo_Edition.sort_index().plot();

# %%
# 2
oo_no_medals = oo[oo.Medal=='NaN']
oo_no_medals
# Out:
# Empty DataFrame
# Columns: [City, Edition, Sport, Discipline, Athlete, NOC, Gender, Event, Event_gender, Medal]
# Index: []

# %% [markdown]
# zu 2: keine Ahnung wie man sieht, welches Land ohne Medalie ist

# %% [markdown]
# ### seine Lösung

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
oo = pd.read_csv('./ALL MEDALISTS.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.Edition.value_counts().plot();

# %%
type(oo.Edition.value_counts())
# also Problem ist das value_counts() returnt Series: Index=Jahr: ist aber nicht sortiert
# Out:
# pandas.core.series.Series

# %%
oo.Edition.value_counts().sort_index()
# Out:
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# Name: Edition, dtype: int64

# %%
oo.Edition.value_counts().sort_index().plot();

# %%
# 2
'''
Vorgehen:

NOC der von oo mit allen NOC der Welt vergleichen. Wenn NOC in oo nicht vorkommt => dieses Land hat keine Medalie gewonnen

'''
lo = oo[oo.Edition == 2008] # nur Einträge für 2008 rausholen
lo.head()
# Out:
#           City  Edition     Sport Discipline           Athlete  NOC Gender  \
# 27174  Beijing     2008  Aquatics     Diving    GALPERIN, Gleb  RUS    Men
# 27175  Beijing     2008  Aquatics     Diving  MITCHAM, Matthew  AUS    Men
# 27176  Beijing     2008  Aquatics     Diving       ZHOU, Luxin  CHN    Men
# 27177  Beijing     2008  Aquatics     Diving         WANG, Xin  CHN  Women
# 27178  Beijing     2008  Aquatics     Diving      CHEN, Ruolin  CHN  Women
#
#               Event Event_gender   Medal
# 27174  10m platform            M  Bronze
# 27175  10m platform            M    Gold
# 27176  10m platform            M  Silver
# 27177  10m platform            W  Bronze
# 27178  10m platform            W    Gold

# %%
noc = pd.read_csv('./IOC COUNTRY CODES.csv')
noc.head()
# Out:
#            Country Int Olympic Committee code ISO code        Country.1
# 0      Afghanistan                        AFG       AF      Afghanistan
# 1          Albania                        ALB       AL          Albania
# 2          Algeria                        ALG       DZ          Algeria
# 3  American Samoa*                        ASA       AS  American Samoa*
# 4          Andorra                        AND       AD          Andorra

# %%
noc[noc['Country'] != noc['Country.1'] ] # hier wird gecheckt, ob sicht die Spalten Country und Country.1 unterscheiden. Da Tabelle leer => sind identisch
# Out:
# Empty DataFrame
# Columns: [Country, Int Olympic Committee code, ISO code, Country.1]
# Index: []

# %%
noc.set_index('Int Olympic Committee code', inplace=True) # index wechseln
noc.head()
# Out:
#                                     Country ISO code        Country.1
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra

# %%
medal_2008 = lo.NOC.value_counts() # zählt welches Land wieviel Medalien gewonnen hat (eigentlich zum Gruppieren)
medal_2008
# Out:
# USA    315
# CHN    184
# AUS    149
# RUS    143
# GER    101
#       ...
# VIE      1
# MRI      1
# ISR      1
# PAN      1
# SUD      1
# Name: NOC, Length: 86, dtype: int64

# %%
noc['medal_2008'] = medal_2008 # neue Spalte (Series) in noc-Tabelle einfügen nämlich die gruppierten Länder mit Medalien aus der ersten Tabelle. Da noc-Tabelle den Index NOC hat => werden die Einträge für passende Länder/Index-Namen gemacht
noc.head() # wo NaN => dieses Land keine Medale gewonnen
# Out:
#                                     Country ISO code        Country.1  \
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra
#
#                             medal_2008
# Int Olympic Committee code
# AFG                                1.0
# ALB                                NaN
# ALG                                2.0
# ASA                                NaN
# AND                                NaN

# %%
noc[noc.medal_2008.isnull()]
# Out:
#                                         Country ISO code            Country.1  \
# Int Olympic Committee code
# ALB                                     Albania       AL              Albania
# ASA                             American Samoa*       AS      American Samoa*
# AND                                     Andorra       AD              Andorra
# ANG                                      Angola       AO               Angola
# ANT                         Antigua and Barbuda       AG  Antigua and Barbuda
# ...                                         ...      ...                  ...
# URU                                     Uruguay       UY              Uruguay
# VAN                                     Vanuatu       VU              Vanuatu
# ISV                             Virgin Islands*       VI      Virgin Islands*
# YEM                                       Yemen       YE                Yemen
# ZAM                                      Zambia       ZM               Zambia
#
# ...
