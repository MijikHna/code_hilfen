# %% [markdown]
# # 5 - Basic Plotting

# %% [markdown]
# ## 1 - Basic Plotting
# * `import matplotlib.pyplot as plt`
# * `%matplotlib inline` - damit Plot in Jupyter-Notebook angezeigt werden anstatt als external Plot dargestellt = Plots inline darstellen
# * es gibt auch OO-Plot-Libraries
# * Plots werden durch Initialisieren der `axis` bzw. `figure` erstellt
# * für einfache Plots reicht auch `pyplot()`

# %% [markdown]
# ## 2 - Plot types
# * `plot()` - plottet
#     * `plot(kind='line')` - line ist auch default
#     * `plot(kind='bar')` - um Gruppen zu vergleichen
#     * `plot(kind='barh')` - horisontale Bars
#     * `plot(kind='pie')`

# %%
import pandas as pd
import pandas

import matplotlib.pyplot as plt
# %matplotlib inline

oo = pd.read_csv('./ALL MEDALISTS.csv', skiprows=4)

# %%
fo = oo[oo.Edition == 1896]
fo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
fo.Sport.value_counts()
# Out:
# Gymnastics       45
# Athletics        37
# Cycling          16
# Shooting         15
# Aquatics         11
# Tennis           10
# Fencing           8
# Weightlifting     6
# Wrestling         3
# Name: Sport, dtype: int64

# %%
fo.Sport.value_counts().plot();

# %%
fo.Sport.value_counts().plot(kind='line');

# %%
fo.Sport.value_counts().plot(kind='bar');

# %%
fo.Sport.value_counts().plot(kind='barh');

# %%
fo.Sport.value_counts().plot(kind='pie');

# %% [markdown]
# ## 3 - Colors
# * plot(color='red')
#     * Farben kann man auf matplotlib anschauen
# * Matplotlib hat viele unterschiedliche Farben für `color` (siehe Doku)

# %%
fo.Sport.value_counts().plot(color='plum');

# %%
fo.Sport.value_counts().plot(kind='bar', color='maroon');

# %% [markdown]
# ## 4 - Figsize
# * ist Option wo man Größe des Plots einstellen kann
# * `plot(figsize=(5,5))`
#     * `figsize ist Tupel (`figsize=(width, height))

# %%
fo.Sport.value_counts().plot();

# %%
fo.Sport.value_counts().plot(figsize=(10,3));

# %% [markdown]
# ## 5 - Colormaps
# * Colormaps sind in Matplotlib integriert
# * Drei Klassen
#     * Sequential = Gradient => wenn Daten sich langsam ändern
#     * Diverging = wenn Daten um Mittelpunkt liegen
#     * Qualitative = Info, die keine Beziehungen zu einander haben
# * `colormap='...'`
# * man muss schauen, ob `kind` ein `color` oder `colormap` braucht
# * => Doku gucken, welche Namen die Colormaps der drei Klassen haben

# %%
fo.Sport.value_counts().plot(kind='pie', colormap='Pastel1');

# %% [markdown]
# ## 6 - Seaborn basic plotting
# * = Lib basierend auf Matplotlib
# * bessere statistische Plots
# * ~ Erweiterung von Matplotlib
# * auf deren Seite kann man Bsp für plots ansehen
# * Seaborn anstelle von Matplotlib benutzen, wenn man kompliziertere Plots machen will

# %%
import seaborn as sns

# %% [markdown]
# ### `countplot`
# * hat ähnliche parameter wie matplotplotlib
# * `seaboard.countplot(x=None, y=None, hue=None, data=None, order=None, order=None, hue_order=None, orient=None, color=None, palette=None)`
#     * `data` = DataFrame zum Ploten
#     * `hue` - Kategorien für den Plot => Kategorie bekommt eigene Farbe, dann Stats der Kategorie haben unterschiedlen Gradien
#     + `order` - Sequence wenn man hue benutzt
#     * `palette` = Farben

# %%
sns.countplot(x='Medal', data=oo);

# %%
sns.countplot(x='Medal', data=oo, hue='Gender');
# wie man sieht x wird noch in men udn women utnerteilt

# %% [markdown]
# ## 7 - Challenge/Solution
# 1. Anzahl der Medale von Chinesen (men und women) in 2008 ploten
#     1. mit plt
#     2. mit sns
# 2. Colormaps benutzen
# 3. für jeden Geschlecht Medalen printen

# %% [markdown]
# #### Meine Lösung

# %%
#1.1
chinese = oo[(oo.NOC=='CHN') & (oo.Edition==2008)]
chinese.head()
# Out:
#           City  Edition     Sport Discipline       Athlete  NOC Gender  \
# 27176  Beijing     2008  Aquatics     Diving   ZHOU, Luxin  CHN    Men
# 27177  Beijing     2008  Aquatics     Diving     WANG, Xin  CHN  Women
# 27178  Beijing     2008  Aquatics     Diving  CHEN, Ruolin  CHN  Women
# 27180  Beijing     2008  Aquatics     Diving      QIN, Kai  CHN    Men
# 27181  Beijing     2008  Aquatics     Diving     HE, Chong  CHN    Men
#
#                 Event Event_gender   Medal
# 27176    10m platform            M  Silver
# 27177    10m platform            W  Bronze
# 27178    10m platform            W    Gold
# 27180  3m springboard            M  Bronze
# 27181  3m springboard            M    Gold

# %%
medals_2008_by_chinese = chinese.Gender.value_counts()
medals_2008_by_chinese
# Out:
# Women    128
# Men       56
# Name: Gender, dtype: int64

# %%
medals_2008_by_chinese.plot(kind='bar');

# %%
#1.2
sns.countplot(x='Medal', data=chinese, hue='Gender');

# %% [markdown]
# #### Seine Lösung

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

oo: pd.core.frame.DataFrame = pd.read_csv('ALL MEDALISTS.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
# 1.1
team_china: pd.core.frame.DataFrame = oo[(oo.Edition == 2008) & (oo.NOC == 'CHN')]
team_china.Gender.value_counts()
# Out:
# Women    128
# Men       56
# Name: Gender, dtype: int64

# %%
team_china.Gender.value_counts().plot(kind='bar');

# %%
#1.2
sns.countplot(data=team_china, x='Gender');

# %%
# 2
sns.countplot(data=oo, x='Gender', palette='bwr');

# %%
sns.countplot(x='Medal', data=team_china, hue='Gender');

# %%
sns.countplot(x='Medal', data=team_china, hue='Gender', palette='bwr', order=['Gold', 'Silver', 'Bronze']);
