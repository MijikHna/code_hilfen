# %% [markdown]
# ### Einführung
# * Audioanalyse wird verwendet in ASR (Spracherkennung), Signalverarbeitung, Musiktagging, (Siri, Alexa)
# * Hier werden .wav-Dateien verwendet

# %% [markdown]
# #### Audio Bibliotheken
# 1. **librosa** - Modul für Signalverabeitung (Doku: https://librosa.github.io/librosa/)
# 2. mit `IPyhton.display.Audio` - kann man Audio direkt in Jupyter abspielen.

# %%
import librosa
import os

print(os.getcwd())

#audio_data = '/media/kirill/WindowsD/Programmieren/ONLINE-RESSOURCEN/Nuanceprog/Python/AudioBearbietung/audio/samplecreate hiphop choir loop.wav'
audio_data = '/media/kirill/WindowsD/Programmieren/ONLINE-RESSOURCEN/Nuanceprog/Python/AudioBearbietung/audio/test.wav'

x, sr = librosa.load(audio_data)
#print(type(x), type(sr))
#print(x.shape, sr)

librosa.load(audio_data)
#librosa.load(audio_data)
# Out:
# /media/kirill/WindowsD/Programmieren/ONLINE-RESSOURCEN/Nuanceprog/Python/AudioBearbietung
# /media/kirill/WindowsD/Programmieren/ONLINE-RESSOURCEN/Nuanceprog/Python/AudioBearbietung/venv/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /media/kirill/WindowsD/Programmieren/ONLINE-RESSOURCEN/Nuanceprog/Python/AudioBearbietung/venv/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
import IPython.display as ipd
ipd.Audio(audio_data)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from playsound import playsound
playsound('/media/kirill/WindowsD/Programmieren/ONLINE-RESSOURCEN/Nuanceprog/Python/AudioBearbietung/audio/test.wav')

# %%
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)

# %%
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()
